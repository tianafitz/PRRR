# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap
from sklearn.cluster import SpectralCoclustering

# %%
# data = pd.read_table("./GSE60361_C1-3005-Expression.txt", index_col=0)
# cell_types = pd.read_table("./zeisel_cell_types.txt", header=None).iloc[:, 0].values
# cell_names = pd.read_table("./zeisel_cell_labels.txt").columns.values
# data = data[cell_names]

data = pd.read_csv("./zeisel_counts.csv", index_col=0)
# cell_types = pd.read_table("./zeisel_cell_types.txt", header=None).iloc[:, 0].values
# cell_names = pd.read_table("./zeisel_cell_labels.txt").columns.values
# data = data[cell_names]

# %%
data.head()
# Out:
#                 Tspan12  Tshz1  Fnbp1l  Adamts15  Cldn12  Rxfp1  \
# 1772071015_C02        0      3       3         0       1      0
# 1772071017_G12        0      1       1         0       1      0
# 1772071017_A05        0      0       6         0       1      0
# 1772071014_B06        3      2       4         0       0      0
# 1772067065_H06        0      2       1         0       0      0
#
#                 X2310042E22Rik  Sema3c  Jam2  Apbb1ip  ...  Tceanc  Msl3  \
# 1772071015_C02               0      11     1        0  ...       0     0
# 1772071017_G12               0       0     0        0  ...       0     0
# 1772071017_A05               2      25     1        0  ...       0     2
# 1772071014_B06               3       1     0        0  ...       0     1
# 1772067065_H06               0      10     0        0  ...       0     4
#
#                 Arhgap6  Mid1  Vamp7  Tmlhe  Zf12  Kdm5d  Uty  Gm20826_loc2
# 1772071015_C02        0     0      5      0     0      0    0             0
# 1772071017_G12        0     0      0      0     0      0    0             0
# 1772071017_A05        0     0      3      0     0      0    7             0
# 1772071014_B06        0     0      0      0     0      0    0             0
# 1772067065_H06        0     0      3      0     0      0    0             0
#
# [5 rows x 16450 columns]

# %%
cell_types = pd.read_csv("./zeisel_types.csv", index_col=0)
cell_types
# Out:
#              cell.id     cell.type
# 1     1772071015_C02  interneurons
# 2     1772071017_G12  interneurons
# 3     1772071017_A05  interneurons
# 4     1772071014_B06  interneurons
# 5     1772067065_H06  interneurons
# ...              ...           ...
# 3001  1772067059_B04   endothelial
# 3002  1772066097_D04   endothelial
# 3003  1772063068_D01   endothelial
# 3004  1772066098_A12   endothelial
# 3005  1772058148_F03   endothelial
#
# [3005 rows x 2 columns]

# %%
NUM_GENES = 1000
gene_variances = data.var(0).values
sorted_idx = np.argsort(-gene_variances)
data_filtered = data.iloc[:, sorted_idx]

# %%
data_filtered.head()
# Out:
#                 Malat1  Plp1  Ttr  Sst  Hbb.bs  Npy  Meg3  Calm1  Trf  \
# 1772071015_C02     822     0    0    0       0  172    18    121    0
# 1772071017_G12     869     0    0    0       0    0    28     68    0
# 1772071017_A05    1237     1    0    0       0  120   146    117    0
# 1772071014_B06    1252     0    0    0       0    0    47    113    0
# 1772067065_H06     271     1    0    0       0    0     5     86    0
#
#                 Hba.a2_loc2  ...  Elf5  Tdrd9  Ptx3  Slc43a1  Tsku  \
# 1772071015_C02            0  ...     0      0     0        0     0
# 1772071017_G12            0  ...     0      0     0        0     0
# 1772071017_A05            0  ...     0      0     0        0     0
# 1772071014_B06            0  ...     0      0     0        0     0
# 1772067065_H06            0  ...     0      0     0        0     0
#
#                 X4931429L15Rik  Ttc24  Rhbg  X5430440P10Rik  X2610028H24Rik
# 1772071015_C02               0      0     0               0               0
# 1772071017_G12               0      0     0               0               0
# 1772071017_A05               0      0     0               0               0
# 1772071014_B06               0      0     0               0               0
# 1772067065_H06               0      0     0               0               0
#
# [5 rows x 16450 columns]

# %%
data_standardized = np.log(data.values.T + 1)
# data_standardized = (data_standardized.T / data_standardized.sum(1)).T
data_standardized = (data_standardized - data_standardized.mean(0)) / data_standardized.std(0)

# %%
pca = PCA(n_components=30)
data_reduced = pca.fit_transform(data_standardized)

# %%
cluster_obj = SpectralCoclustering(n_clusters=9)
cluster_obj.fit(data_reduced)
# Out:
# SpectralCoclustering(n_clusters=9)

# %%
# plt.scatter(data_reduced[:, 0], data_reduced[:, 1], c=cell_types["cell.type"])
# plt.show()

# %%
tsne = TSNE()
data_reduced_tsne = tsne.fit_transform(data_reduced)

# %%
plot_df = pd.DataFrame(data_reduced_tsne, columns=['tsne1', 'tsne2'])
plot_df['cluster_id'] = cell_types["cell.type"] #cell_types.astype(str)
plt.figure(figsize=(7, 7))
sns.scatterplot(data=plot_df, x='tsne1', y='tsne2', hue='cluster_id')
plt.show()
