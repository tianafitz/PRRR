# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sys
import glob

sys.path.append("../../prrr/models")
from prrr import PRRR
from grrr import GRRR
from sklearn.model_selection import train_test_split
from collections import Counter

import matplotlib
font = {"size": 15}
matplotlib.rc("font", **font)
# EXPRESSION_FILE = "../../data/GTEx_gene_expression/gtex_expression_Vagina.csv"
# tissue_expression_files = glob.glob("../../data/GTEx_gene_expression/*")
tissue_expression_files = ["../../data/GTEx_gene_expression/gtex_expression_Spleen.csv"]

# %%
data = pd.read_excel("../../data/gtex/GTEx_Analysis_2015-01-12_Annotations_SubjectPhenotypesDD.xlsx")
integer_varnames = data.VARNAME.values[["encoded value" in x for x in data.TYPE.values]]
integer_varnames = [i for i in integer_varnames if i.startswith('MH')]
integer_varnames
# Out:
# ['MHABNWBC',
#  'MHALS',
#  'MHALZDMT',
#  'MHALZHMR',
#  'MHARTHTS',
#  'MHASCITES',
#  'MHASTHMA',
#  'MHBCTINF',
#  'MHBLDDND',
#  'MHBLDOCNT',
#  'MHCANCER5',
#  'MHCANCERC',
#  'MHCANCERNM',
#  'MHCLLULTS',
#  'MHCLRD',
#  'MHCOCAINE5',
#  'MHCOPD',
#  'MHCOUGHU',
#  'MHCVD',
#  'MHDLYSIS',
#  'MHDMNTIA',
#  'MHDPRSSN',
#  'MHDTND72H',
#  'MHENCEPHA',
#  'MHEURO5',
#  'MHFLU',
#  'MHFNGINF',
#  'MHFVRU',
#  'MHGNRR12M',
#  'MHHEPBCT',
#  'MHHEPCCT',
#  'MHHEROIN',
#  'MHHGH',
#  'MHHIVCT',
#  'MHHIVNT',
#  'MHHMPHLIA',
#  'MHHMPHLIAB',
#  'MHHRTATT',
#  'MHHRTDIS',
#  'MHHRTDISB',
#  'MHHTN',
#  'MHINFLNE',
#  'MHIVDRG5',
#  'MHJAKOB',
#  'MHLAPTHU',
#  'MHLUPUS',
#  'MHLVRDIS',
#  'MHMENINA',
#  'MHMS',
#  'MHMSXWMA',
#  'MHMSXWMB',
#  'MHNEPH',
#  'MHNGHTSWT',
#  'MHNPHYS4W',
#  'MHNRTHEUR',
#  'MHOPNWND',
#  'MHOPPINF',
#  'MHORGNTP',
#  'MHOSTMYLTS',
#  'MHPLLABS',
#  'MHPNMIAB',
#  'MHPNMNIA',
#  'MHPRCNP',
#  'MHPRKNSN',
#  'MHPSBLDCLT',
#  'MHRA',
#  'MHRBSANML',
#  'MHREYES',
#  'MHRNLFLR',
#  'MHSARS',
#  'MHSCHZ',
#  'MHSCLRDRM',
#  'MHSDRGABS',
#  'MHSEPSIS',
#  'MHSKNSPT',
#  'MHSMLPXCT',
#  'MHSMLPXVC',
#  'MHSRCDSS',
#  'MHSRGHM',
#  'MHSTD',
#  'MHSTRDLT',
#  'MHSUBABSA',
#  'MHSUBABSB',
#  'MHSXMDA',
#  'MHSXMDB',
#  'MHSYPH12M',
#  'MHSZRSU',
#  'MHT1D',
#  'MHT2D',
#  'MHTBHX',
#  'MHTEMPU',
#  'MHTTOO12M',
#  'MHTTOONP',
#  'MHTXCEXP',
#  'MHUK8096',
#  'MHUREMIA',
#  'MHWKNSSU',
#  'MHWNVCT',
#  'MHWNVHX',
#  'MHWTLSUA',
#  'MHWTLSUB']

# %%
decimal_varnames = data.VARNAME.values[["decimal" in x for x in data.TYPE.values]]
decimal_varnames

# %%
expression_data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e5306b71bbea> in <module>
# ----> 1 expression_data.shape
#
# NameError: name 'expression_data' is not defined

# %%
i = 1
for f in tissue_expression_files:    
    EXPRESSION_FILE = f
    print(EXPRESSION_FILE)
    METADATA_PATH = (
        "../../data/GTEx_metadata/GTEx_Analysis_2017-06-05_v8_Annotations_SubjectPhenotypesDS.txt"
    )
    NUM_GENES = 5000
#     TISSUE = ""

    expression_data = pd.read_csv(EXPRESSION_FILE, index_col=0)
    v8_metadata = pd.read_table(METADATA_PATH)


    ## Align subjects
    subj_ids_expression = expression_data.index.str.split("-").str[:2].str.join("-")
    expression_data["SUBJID"] = subj_ids_expression
    shared_subj_ids = np.intersect1d(subj_ids_expression, v8_metadata.SUBJID.values)
    v8_metadata.index = v8_metadata.SUBJID.values
    v8_metadata = v8_metadata.transpose()[shared_subj_ids].transpose()

    expression_data = expression_data.drop_duplicates("SUBJID")
    expression_data.index = expression_data["SUBJID"]
    expression_data = expression_data.transpose()[shared_subj_ids].transpose()

    expression_data = expression_data.drop("SUBJID", axis=1)

    assert np.array_equal(v8_metadata.index.values, expression_data.index.values)


    # Get most variable genes
    n_genes = 200
    Y = expression_data.values.astype(int)
    Ylog = np.log(Y + 1)
    gene_vars = Ylog.std(0)
    sorted_idx = np.argsort(-gene_vars)

    Y = Y[:, sorted_idx[:n_genes]]


    # Pick a few metadata columns
    metadata_cols = []
    dummy_vars = integer_varnames
    nondummy_vars = np.setdiff1d(metadata_cols, dummy_vars)
    dummy_list = []
    for dummy_var in dummy_vars:
        curr_dummies = pd.get_dummies(v8_metadata[dummy_var]).rename(columns=lambda x:dummy_var + '_' + str(x))
        dummy_list.append(curr_dummies)
        
        
    for nondummy_var in nondummy_vars:
        v8_metadata[nondummy_var] = (v8_metadata[nondummy_var] - v8_metadata[nondummy_var].mean()) / v8_metadata[nondummy_var].std()

    X_df = pd.concat(dummy_list, axis=1)
#     X_df = pd.DataFrame()

    for nondummy_var in nondummy_vars:
        X_df = pd.concat([X_df, v8_metadata[nondummy_var]], axis=1)
    
    # cut out unknowns
    X_df_un = X_df.columns.values[[("_96" in x) or ("_97" in x) or ("_98" in x) or ("_99" in x) for x in X_df.columns.values]]
    X_df = X_df.drop(columns = X_df_un, axis = 1)

    # Fit model
    k = 2
#     prrr = PRRR(n_latent_dim=k)
    grrr = GRRR(k)
    cell_total_counts = np.expand_dims(Y.sum(1).astype("float32"), 1)

    rrr_results_g = grrr.fit(X=X_df.values, Y=Y, size_factors=cell_total_counts, use_vi=False)
#     rrr_results_p = prrr.fit(X=X_df.values, Y=Y, size_factors=cell_total_counts)

#     A_lognormal_mean = grrr.param_dict["A_mean"].numpy()
#     A_stddev = grrr.param_dict["A_stddev"].numpy()
#     B_lognormal_mean = grrr.param_dict["B_mean"].numpy()
#     B_stddev = grrr.param_dict["B_stddev"].numpy()

#     A_est = np.exp(A_lognormal_mean + 0.5 * A_stddev ** 2)
#     B_est = np.exp(B_lognormal_mean + 0.5 * B_stddev ** 2)
#     AB_est = A_est @ B_est

#     cur = plt.figure(i, figsize=(7, 7))
#     i += 1
#     plt.scatter(AB_est[0, :], AB_est[1, :])
#     plt.xlabel("Gene coefficients (male)", fontsize=25)
#     plt.ylabel("Gene coefficients (female)", fontsize=25)
#     plt.tight_layout()
#     # plt.savefig("../../figures/plots/gtex_male_vs_female.png")
#     cur2 = plt.figure(i, figsize=(7, 7))
#     sns.heatmap(AB_est)
#     i += 1

# plt.show()
# Out:
# ../../data/GTEx_gene_expression/gtex_expression_Spleen.csv

# %%
A = grrr.param_dict["A"].numpy()
B = grrr.param_dict["B"].numpy()
AB_est_g = A @ B

# A_lognormal_mean = prrr.param_dict["A_mean"].numpy()
# A_stddev = prrr.param_dict["A_stddev"].numpy()
# B_lognormal_mean = prrr.param_dict["B_mean"].numpy()
# B_stddev = prrr.param_dict["B_stddev"].numpy()

# A_est = np.exp(A_lognormal_mean + 0.5 * A_stddev ** 2)
# B_est = np.exp(B_lognormal_mean + 0.5 * B_stddev ** 2)
# AB_est_p = A_est @ B_est

# cur = plt.figure(i, figsize=(7, 7))
# plt.scatter(AB_est[0, :], AB_est[1, :])
# plt.xlabel("Gene coefficients (male)", fontsize=25)
# plt.ylabel("Gene coefficients (female)", fontsize=25)
# plt.tight_layout()
# # plt.savefig("../../figures/plots/gtex_male_vs_female.png")
# cur2 = plt.figure(i, figsize=(7, 7))
sns.heatmap(AB_est_g)
# plt.show()
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(pd.DataFrame(AB_est_g, index=X_df.columns), figsize=(10, 50), yticklabels=True)

# %%
X_df.columns
# Out:
# Index(['ETHNCTY_0', 'ETHNCTY_1', 'SEX_1', 'SEX_2', 'RACE_1', 'RACE_2',
#        'RACE_3', 'RACE_4', 'DTHATPSY_0.0', 'DTHATPSY_1.0',
#        ...
#        'MHUK8096_1', 'MHUREMIA_0', 'MHWKNSSU_0', 'MHWKNSSU_1', 'MHWNVCT_0',
#        'MHWNVHX_0', 'MHWTLSUA_0', 'MHWTLSUA_1', 'MHWTLSUB_0', 'MHWTLSUB_1'],
#       dtype='object', length=238)

# %%
v8_metadata["ETHNCTY"].value_counts()
# Out:
# 0     165
# 99     79
# 98      7
# 1       3
# Name: ETHNCTY, dtype: int64

# %%
cur1 = plt.figure(1, figsize=(7, 7))
plt.scatter(AB_est[8, :], AB_est[9, :])
plt.xlabel("Gene coefficients (male)", fontsize=25)
plt.ylabel("Gene coefficients (female)", fontsize=25)
plt.tight_layout()  

cur2 = plt.figure(2, figsize=(7, 7))
plt.scatter(AB_est[1, :], AB_est[2, :])
plt.xlabel("Gene coefficients (male)", fontsize=25)
plt.ylabel("Gene coefficients (female)", fontsize=25)
plt.tight_layout()  

cur3 = plt.figure(3, figsize=(7, 7))
sns.heatmap(B_lognormal_mean)

cur4 = plt.figure(4, figsize=(7, 7))
sns.heatmap(A_lognormal_mean)

plt.show()

# %%
sns.heatmap(B_lognormal_mean)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(AB_est)
# Out:
# <AxesSubplot:>

# %%
X_df.columns
# Out:
# Index([1, 2, 1, 2, 3, 99, 0, 1, 98, 99, 'HGHT', 'WGHT'], dtype='object')

# %%
for x in integer_varnames:
    s = v8_metadata[x].value_counts().to_frame()
    try:
        print(s.loc[1])
    except:
        continue
# Out:
# MHABNWBC    138
# Name: 1, dtype: int64
# MHALS    1
# Name: 1, dtype: int64
# MHALZDMT    1
# Name: 1, dtype: int64
# MHARTHTS    18
# Name: 1, dtype: int64
# MHASCITES    4
# Name: 1, dtype: int64
# MHASTHMA    28
# Name: 1, dtype: int64
# MHBCTINF    15
# Name: 1, dtype: int64
# MHBLDDND    19
# Name: 1, dtype: int64
# MHBLDOCNT    1
# Name: 1.0, dtype: int64
# MHCANCER5    4
# Name: 1, dtype: int64
# MHCANCERC    3
# Name: 1.0, dtype: int64
# MHCANCERNM    15
# Name: 1, dtype: int64
# MHCLLULTS    4
# Name: 1, dtype: int64
# MHCLRD    8
# Name: 1, dtype: int64
# MHCOCAINE5    16
# Name: 1, dtype: int64
# MHCOPD    35
# Name: 1, dtype: int64
# MHCVD    26
# Name: 1, dtype: int64
# MHDLYSIS    4
# Name: 1, dtype: int64
# MHDMNTIA    1
# Name: 1, dtype: int64
# MHDPRSSN    33
# Name: 1, dtype: int64
# MHDTND72H    5
# Name: 1, dtype: int64
# MHEURO5    5
# Name: 1, dtype: int64
# MHFLU    1
# Name: 1, dtype: int64
# MHFNGINF    5
# Name: 1, dtype: int64
# MHFVRU    2
# Name: 1, dtype: int64
# MHHEROIN    7
# Name: 1, dtype: int64
# MHHRTATT    26
# Name: 1, dtype: int64
# MHHRTDIS    39
# Name: 1, dtype: int64
# MHHRTDISB    1
# Name: 1, dtype: int64
# MHHTN    118
# Name: 1, dtype: int64
# MHIVDRG5    1
# Name: 1, dtype: int64
# MHLUPUS    3
# Name: 1, dtype: int64
# MHLVRDIS    7
# Name: 1, dtype: int64
# MHMS    1
# Name: 1, dtype: int64
# MHMSXWMA    3
# Name: 1, dtype: int64
# MHMSXWMB    1
# Name: 1, dtype: int64
# MHNEPH    1
# Name: 1, dtype: int64
# MHNGHTSWT    1
# Name: 1, dtype: int64
# MHNPHYS4W    2
# Name: 1, dtype: int64
# MHNRTHEUR    12
# Name: 1.0, dtype: int64
# MHOPNWND    11
# Name: 1.0, dtype: int64
# MHOPPINF    1
# Name: 1, dtype: int64
# MHORGNTP    7
# Name: 1, dtype: int64
# MHOSTMYLTS    3
# Name: 1, dtype: int64
# MHPLLABS    12
# Name: 1, dtype: int64
# MHPNMIAB    19
# Name: 1, dtype: int64
# MHPNMNIA    19
# Name: 1, dtype: int64
# MHPRCNP    1
# Name: 1, dtype: int64
# MHPRKNSN    1
# Name: 1, dtype: int64
# MHPSBLDCLT    8
# Name: 1, dtype: int64
# MHRA    3
# Name: 1, dtype: int64
# MHRNLFLR    21
# Name: 1, dtype: int64
# MHSCHZ    4
# Name: 1, dtype: int64
# MHSCLRDRM    1
# Name: 1.0, dtype: int64
# MHSDRGABS    2
# Name: 1, dtype: int64
# MHSEPSIS    8
# Name: 1, dtype: int64
# MHSKNSPT    2
# Name: 1, dtype: int64
# MHSMLPXVC    1
# Name: 1, dtype: int64
# MHSRCDSS    1
# Name: 1, dtype: int64
# MHSRGHM    4
# Name: 1, dtype: int64
# MHSTD    2
# Name: 1, dtype: int64
# MHSTRDLT    2
# Name: 1, dtype: int64
# MHSUBABSA    1
# Name: 1, dtype: int64
# MHSUBABSB    1
# Name: 1, dtype: int64
# MHSXMDB    1
# Name: 1, dtype: int64
# MHSZRSU    11
# Name: 1, dtype: int64
# MHT1D    12
# Name: 1, dtype: int64
# MHT2D    42
# Name: 1, dtype: int64
# MHTBHX    2
# Name: 1, dtype: int64
# MHTTOO12M    1
# Name: 1, dtype: int64
# MHTTOONP    3
# Name: 1, dtype: int64
# MHTXCEXP    8
# Name: 1, dtype: int64
# MHUK8096    5
# Name: 1, dtype: int64
# MHWKNSSU    8
# Name: 1, dtype: int64
# MHWTLSUA    6
# Name: 1, dtype: int64
# MHWTLSUB    1
# Name: 1, dtype: int64

# %%
tissue_expression_files
# Out:
# ['../../data/GTEx_gene_expression/gtex_expression_Brain - Nucleus accumbens (basal ganglia).csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Nerve - Tibial.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Hypothalamus.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Cortex.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Whole Blood.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Pancreas.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Esophagus - Muscularis.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Cervix - Ectocervix.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Putamen (basal ganglia).csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Esophagus - Mucosa.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Lung.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Cervix - Endocervix.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Substantia nigra.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Skin - Not Sun Exposed (Suprapubic).csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Spinal cord (cervical c-1).csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Adipose - Subcutaneous.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Minor Salivary Gland.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Artery - Coronary.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Adrenal Gland.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Breast - Mammary Tissue.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Amygdala.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Cerebellar Hemisphere.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Artery - Aorta.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Spleen.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Cells - Cultured fibroblasts.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Esophagus - Gastroesophageal Junction.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Kidney - Cortex.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Skin - Sun Exposed (Lower leg).csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Adipose - Visceral (Omentum).csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Colon - Sigmoid.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Fallopian Tube.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Cells - EBV-transformed lymphocytes.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Heart - Left Ventricle.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Prostate.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Uterus.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Ovary.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Artery - Tibial.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Pituitary.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Stomach.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Muscle - Skeletal.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Testis.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Heart - Atrial Appendage.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Vagina.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Liver.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Small Intestine - Terminal Ileum.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Caudate (basal ganglia).csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Kidney - Medulla.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Anterior cingulate cortex (BA24).csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Bladder.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Hippocampus.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Colon - Transverse.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Cerebellum.csv',
#  '../../data/GTEx_gene_expression/gtex_expression_Brain - Frontal Cortex (BA9).csv']
